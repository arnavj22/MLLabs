# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
iris_path = "/content/drive/MyDrive/ML/Lab 8/iris.csv"
df = pd.read_csv(iris_path)

# %%
def discretize(df):
  for i in list(df):
    if i != "variety":
      col = df[i]
      print(i)
      bins = pd.cut(col, 3, labels = ["1", "2", "3"]) # Discretizes to bins
      df[i] = bins

# %%
discretize(df)
# Out:
# sepal.length
# sepal.width
# petal.length
# petal.width

# %%
y = df['variety']
X = df.drop(['variety'], axis = 1)

# %%
import sklearn
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = DecisionTreeClassifier()
y_pred = model.fit(X_train, y_train).predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print("Test Accuracy: ", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Test Accuracy:  1.0
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plot_tree(model)
# Out:
# [Text(0.5357142857142857, 0.9166666666666666, 'X[3] <= 1.5\ngini = 0.665\nsamples = 120\nvalue = [39, 37, 44]'),
#  Text(0.4642857142857143, 0.75, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.6071428571428571, 0.75, 'X[3] <= 2.5\ngini = 0.496\nsamples = 81\nvalue = [0, 37, 44]'),
#  Text(0.35714285714285715, 0.5833333333333334, 'X[2] <= 2.5\ngini = 0.18\nsamples = 40\nvalue = [0, 36, 4]'),
#  Text(0.21428571428571427, 0.4166666666666667, 'X[0] <= 1.5\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.14285714285714285, 0.25, 'X[1] <= 1.5\ngini = 0.18\nsamples = 10\nvalue = [0, 9, 1]'),
#  Text(0.07142857142857142, 0.08333333333333333, 'gini = 0.198\nsamples = 9\nvalue = [0, 8, 1]'),
#  Text(0.21428571428571427, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.2857142857142857, 0.25, 'gini = 0.0\nsamples = 25\nvalue = [0, 25, 0]'),
#  Text(0.5, 0.4166666666666667, 'X[0] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.42857142857142855, 0.25, 'X[1] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.35714285714285715, 0.08333333333333333, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5714285714285714, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8571428571428571, 0.5833333333333334, 'X[2] <= 2.5\ngini = 0.048\nsamples = 41\nvalue = [0, 1, 40]'),
#  Text(0.7857142857142857, 0.4166666666666667, 'X[1] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.7142857142857143, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8571428571428571, 0.25, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.9285714285714286, 0.4166666666666667, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 37]')]

# %%
print(list(X))
# Out:
# ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']
